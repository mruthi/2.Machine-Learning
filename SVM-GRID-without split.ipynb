# %%
import pandas as pd

# %%
import sklearn

# %%
import numpy as ph

# %%
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#sklearn.__version__

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={"kernel":["sigmoid","poly","linear","rbf"],"C":[10,100,1000,2000,3000]}
grid= GridSearchCV(SVR(), param_grid, refit=True, verbose=3, n_jobs=-1)
#fitting the model for grid search
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\Users\saran\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'kernel': ['sigmoid', 'poly', 'linear', 'rbf']},
#              verbose=3)

# %%
#printing best parameters after tuning
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 1000, 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.186545      0.018332         0.043777        0.003194      10
# 1        0.127051      0.006109         0.024122        0.000047      10
# 2        0.131463      0.005824         0.024134        0.000052      10
# 3        0.155330      0.003925         0.056152        0.000046      10
# 4        0.182839      0.007349         0.042484        0.003138     100
# 5        0.130047      0.003662         0.024208        0.000189     100
# 6        0.248449      0.013433         0.022456        0.003228     100
# 7        0.147883      0.003779         0.057779        0.003198     100
# 8        0.173351      0.003969         0.040114        0.000035    1000
# 9        0.158972      0.006079         0.026241        0.004329    1000
# 10       0.842857      0.100066         0.022460        0.003193    1000
# 11       0.157369      0.009568         0.056157        0.000036    1000
# 12       0.176759      0.005075         0.041731        0.003233    2000
# 13       0.191063      0.005900         0.024076        0.000036    2000
# 14       1.333213      0.086944         0.019240        0.003889    2000
# 15       0.158980      0.003023         0.056133        0.000033    2000
# 16       0.174788      0.007349         0.043319        0.008217    3000
# 17       0.223940      0.014856         0.024087        0.000052    3000
# 18       2.517881      0.560162         0.020867        0.003947    3000
# 19       0.158928      0.003233         0.059421        0.003912    3000
#
#    param_kernel                            params  split0_test_score  \
# 0       sigmoid    {'C': 10, 'kernel': 'sigmoid'}          -0.116743
# 1          poly       {'C': 10, 'kernel': 'poly'}          -0.125153
# 2        linear     {'C': 10, 'kernel': 'linear'}          -0.018943
# 3           rbf        {'C': 10, 'kernel': 'rbf'}          -0.110409
# 4       sigmoid   {'C': 100, 'kernel': 'sigmoid'}          -0.142455
# 5          poly      {'C': 100, 'kernel': 'poly'}          -0.132885
# 6        linear    {'C': 100, 'kernel': 'linear'}           0.559313
# 7           rbf       {'C': 100, 'kernel': 'rbf'}          -0.160182
# 8       sigmoid  {'C': 1000, 'kernel': 'sigmoid'}          -2.043140
# 9          poly     {'C': 1000, 'kernel': 'poly'}          -0.080527
# 10       linear   {'C': 1000, 'kernel': 'linear'}           0.736398
# 11          rbf      {'C': 1000, 'kernel': 'rbf'}          -0.155430
# 12      sigmoid  {'C': 2000, 'kernel': 'sigmoid'}          -7.209317
# 13         poly     {'C': 2000, 'kernel': 'poly'}          -0.020567
# 14       linear   {'C': 2000, 'kernel': 'linear'}           0.682349
# 15          rbf      {'C': 2000, 'kernel': 'rbf'}          -0.143510
# 16      sigmoid  {'C': 3000, 'kernel': 'sigmoid'}         -15.561853
# 17         poly     {'C': 3000, 'kernel': 'poly'}           0.037700
# 18       linear   {'C': 3000, 'kernel': 'linear'}           0.677778
# 19          rbf      {'C': 3000, 'kernel': 'rbf'}          -0.128958
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.119312          -0.085214          -0.108210
# 1           -0.081505          -0.111907          -0.131602
# 2            0.029886           0.022167           0.003112
# 3           -0.097459          -0.074488          -0.099597
# 4           -0.160831          -0.117544          -0.137984
# 5           -0.082461          -0.129220          -0.139962
# 6            0.521798           0.547691           0.538805
# 7           -0.107253          -0.123430          -0.137753
# 8           -2.686121          -2.194563          -2.210858
# 9           -0.028469          -0.073376          -0.086611
# 10           0.675162           0.680002           0.699377
# 11          -0.098267          -0.123724          -0.137137
# 12          -9.282940          -7.776578          -7.745074
# 13           0.035685          -0.011468          -0.024587
# 14           0.630642           0.750714           0.646368
# 15          -0.087595          -0.113312          -0.128591
# 16         -20.498908         -17.095474         -16.750877
# 17           0.098496           0.049291           0.035615
# 18           0.626814           0.732806           0.633479
# 19          -0.075578          -0.100199          -0.116051
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.108716        -0.107639        0.012029               10
# 1           -0.179328        -0.125899        0.031794               12
# 2           -0.066653        -0.006086        0.034672                6
# 3           -0.124428        -0.101276        0.016459                9
# 4           -0.130402        -0.137843        0.014263               15
# 5           -0.189219        -0.134749        0.033948               14
# 6            0.508518         0.535225        0.018122                4
# 7           -0.209551        -0.147634        0.035511               17
# 8           -1.942521        -2.215441        0.255409               18
# 9           -0.134493        -0.080695        0.033795                8
# 10           0.677952         0.693778        0.022955                1
# 11          -0.206405        -0.144193        0.036262               16
# 12          -6.891719        -7.781126        0.821557               19
# 13          -0.076360        -0.019459        0.035693                7
# 14           0.722261         0.686467        0.045056                2
# 15          -0.193992        -0.133400        0.035492               13
# 16         -15.012168       -16.983856        1.914783               20
# 17          -0.020924         0.040035        0.038064                5
# 18           0.698692         0.673914        0.039876                3
# 19          -0.179304        -0.120018        0.034578               11

# %%
age_input=float(input("age:"))
bmi_input=float(input("BMI:"))
children_input=int(input("children:"))
sex_male_input=int(input("sex male 0 or 1:"))
smoker_yes_input=int(input("smoker yes 0 or 1:"))
# Out:
# age:23
# BMI:34.5
# children:1
# sex male 0 or 1:0
# smoker yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future Prediction={}".format(Future_Prediction))
# Out:
# Future Prediction=[27593.59652031]
# C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
