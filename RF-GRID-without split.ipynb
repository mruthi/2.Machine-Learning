# %%
import sklearn

# %%
import numpy as np

# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid={"criterion":["mae","mse","absolute_error",'poisson','squared_error','friedman_mse'],"max_features":["auto","sqrt","log2"],"n_estimators":[10,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\Users\saran\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 100 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 16 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'friedman_mse', 'squared_error', 'poisson'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'friedman_mse', 'absolute_error', 'poisson', 'squared_error'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'friedman_mse', 'absolute_error', 'poisson', 'squared_error'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 16 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'friedman_mse', 'squared_error', 'poisson'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\saran\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\saran\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.81545195 0.83013745 0.82046117 0.83109074
#         nan        nan 0.81231851 0.8352609  0.82137749 0.83265134
#         nan        nan 0.81703792 0.83350187 0.81358038 0.83434103
#         nan        nan 0.81854002 0.83137098 0.815528   0.83262686]
#   warnings.warn(
# C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mae', 'mse', 'absolute_error',
#                                        'poisson', 'squared_error',
#                                        'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R score value for best parameter:{}".format(grid.best_params_))
# Out:
# The R score value for best parameter:{'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000000      0.000000         0.000000        0.000000
# 1        0.003125      0.006250         0.000000        0.000000
# 2        0.003125      0.006250         0.000000        0.000000
# 3        0.003125      0.006250         0.000000        0.000000
# 4        0.000000      0.000000         0.000000        0.000000
# 5        0.000000      0.000000         0.000000        0.000000
# 6        0.003126      0.006251         0.000000        0.000000
# 7        0.006250      0.007654         0.000000        0.000000
# 8        0.003126      0.006251         0.000000        0.000000
# 9        0.003125      0.006251         0.000000        0.000000
# 10       0.003125      0.006251         0.000000        0.000000
# 11       0.006250      0.007655         0.000000        0.000000
# 12       0.003124      0.006248         0.000000        0.000000
# 13       0.006251      0.007656         0.000000        0.000000
# 14       0.240637      0.007656         0.009376        0.007655
# 15       2.247606      0.072828         0.047548        0.018350
# 16       0.241725      0.007542         0.009376        0.007655
# 17       2.282428      0.163475         0.043753        0.006249
# 18       0.003125      0.006250         0.000000        0.000000
# 19       0.003654      0.003102         0.000000        0.000000
# 20       0.123722      0.011361         0.008871        0.007301
# 21       1.141494      0.034380         0.064530        0.036195
# 22       0.161982      0.046330         0.016829        0.005466
# 23       1.171045      0.119859         0.046088        0.001718
# 24       0.003125      0.006251         0.000000        0.000000
# 25       0.003125      0.006250         0.000000        0.000000
# 26       0.137448      0.016548         0.015396        0.001039
# 27       0.988738      0.072846         0.048702        0.013698
# 28       0.158753      0.015326         0.013637        0.003035
# 29       0.998354      0.084106         0.046402        0.010161
# 30       0.003261      0.001092         0.000000        0.000000
# 31       0.002905      0.001860         0.000000        0.000000
# 32       0.146392      0.033590         0.025094        0.029323
# 33       1.018369      0.065084         0.043753        0.006250
# 34       0.126398      0.017795         0.015782        0.003370
# 35       0.917893      0.035220         0.040628        0.007655
#
#    param_criterion param_max_features param_n_estimators  \
# 0              mae               auto                 10
# 1              mae               auto                100
# 2              mae               sqrt                 10
# 3              mae               sqrt                100
# 4              mae               log2                 10
# 5              mae               log2                100
# 6              mse               auto                 10
# 7              mse               auto                100
# 8              mse               sqrt                 10
# 9              mse               sqrt                100
# 10             mse               log2                 10
# 11             mse               log2                100
# 12  absolute_error               auto                 10
# 13  absolute_error               auto                100
# 14  absolute_error               sqrt                 10
# 15  absolute_error               sqrt                100
# 16  absolute_error               log2                 10
# 17  absolute_error               log2                100
# 18         poisson               auto                 10
# 19         poisson               auto                100
# 20         poisson               sqrt                 10
# 21         poisson               sqrt                100
# 22         poisson               log2                 10
# 23         poisson               log2                100
# 24   squared_error               auto                 10
# 25   squared_error               auto                100
# 26   squared_error               sqrt                 10
# 27   squared_error               sqrt                100
# 28   squared_error               log2                 10
# 29   squared_error               log2                100
# 30    friedman_mse               auto                 10
# 31    friedman_mse               auto                100
# 32    friedman_mse               sqrt                 10
# 33    friedman_mse               sqrt                100
# 34    friedman_mse               log2                 10
# 35    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 1   {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 2   {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 3   {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 4   {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 5   {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 6   {'criterion': 'mse', 'max_features': 'auto', '...                NaN
# 7   {'criterion': 'mse', 'max_features': 'auto', '...                NaN
# 8   {'criterion': 'mse', 'max_features': 'sqrt', '...                NaN
# 9   {'criterion': 'mse', 'max_features': 'sqrt', '...                NaN
# 10  {'criterion': 'mse', 'max_features': 'log2', '...                NaN
# 11  {'criterion': 'mse', 'max_features': 'log2', '...                NaN
# 12  {'criterion': 'absolute_error', 'max_features'...                NaN
# 13  {'criterion': 'absolute_error', 'max_features'...                NaN
# 14  {'criterion': 'absolute_error', 'max_features'...           0.839374
# 15  {'criterion': 'absolute_error', 'max_features'...           0.854584
# 16  {'criterion': 'absolute_error', 'max_features'...           0.843657
# 17  {'criterion': 'absolute_error', 'max_features'...           0.857480
# 18  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.841396
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.860601
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.849976
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.858417
# 24  {'criterion': 'squared_error', 'max_features':...                NaN
# 25  {'criterion': 'squared_error', 'max_features':...                NaN
# 26  {'criterion': 'squared_error', 'max_features':...           0.835735
# 27  {'criterion': 'squared_error', 'max_features':...           0.854255
# 28  {'criterion': 'squared_error', 'max_features':...           0.844701
# 29  {'criterion': 'squared_error', 'max_features':...           0.857937
# 30  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 31  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 32  {'criterion': 'friedman_mse', 'max_features': ...           0.838674
# 33  {'criterion': 'friedman_mse', 'max_features': ...           0.858702
# 34  {'criterion': 'friedman_mse', 'max_features': ...           0.833325
# 35  {'criterion': 'friedman_mse', 'max_features': ...           0.853355
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.780064           0.823547           0.804988
# 15           0.778043           0.852554           0.821888
# 16           0.768210           0.847272           0.821771
# 17           0.777100           0.856835           0.826088
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.749049           0.837484           0.803234
# 21           0.784382           0.861559           0.827953
# 22           0.770656           0.846257           0.813472
# 23           0.779153           0.858357           0.826994
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26           0.770873           0.848422           0.808921
# 27           0.784223           0.861113           0.827357
# 28           0.762308           0.820739           0.812108
# 29           0.780248           0.860459           0.828375
# 30                NaN                NaN                NaN
# 31                NaN                NaN                NaN
# 32           0.754065           0.844562           0.816831
# 33           0.774430           0.853194           0.826653
# 34           0.768184           0.837774           0.816296
# 35           0.778338           0.863412           0.826931
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2                 NaN              NaN             NaN               17
# 3                 NaN              NaN             NaN               17
# 4                 NaN              NaN             NaN               17
# 5                 NaN              NaN             NaN               17
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8                 NaN              NaN             NaN               17
# 9                 NaN              NaN             NaN               17
# 10                NaN              NaN             NaN               17
# 11                NaN              NaN             NaN               17
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.829287         0.815452        0.020933               14
# 15           0.843618         0.830137        0.028509                8
# 16           0.821396         0.820461        0.028248               10
# 17           0.837951         0.831091        0.029483                7
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.830431         0.812319        0.034329               16
# 21           0.841810         0.835261        0.028350                1
# 22           0.826527         0.821377        0.028630                9
# 23           0.840335         0.832651        0.029250                4
# 24                NaN              NaN             NaN               17
# 25                NaN              NaN             NaN               17
# 26           0.821238         0.817038        0.026643               12
# 27           0.840561         0.833502        0.027236                3
# 28           0.828045         0.813580        0.027785               15
# 29           0.844687         0.834341        0.029352                2
# 30                NaN              NaN             NaN               17
# 31                NaN              NaN             NaN               17
# 32           0.838569         0.818540        0.033597               11
# 33           0.843876         0.831371        0.030476                6
# 34           0.822061         0.815528        0.024885               13
# 35           0.841098         0.832627        0.029762                5

# %%
age_input=float(input("age:"))
bmi_input=float(input("BMI:"))
children_input=int(input("children:"))
sex_male_input=int(input("sex male 0 or 1:"))
smoker_yes_input=int(input("smoker yes 0 or 1:"))
# Out:
# age:43
# BMI:45.2
# children:2
# sex male 0 or 1:0
# smoker yes 0 or 1:1

# %%
Future_predicion=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future Prediction: {}".format(Future_predicion))
# Out:
# Future Prediction: [44663.5179261]
# C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
